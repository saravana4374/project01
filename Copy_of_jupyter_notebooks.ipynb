# %% [markdown]
# <a href="https://colab.research.google.com/github/saravana4374/project01/blob/main/Copy_of_jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("ecommerce_sales_dataset_50000.csv")
df
# Out:
#         order_id customer_id    customer_name        product        category  \
# 0      ORD000001   CUST12067     Allison Hill       Yoga Mat          Sports
# 1      ORD000002   CUST03583      Noah Rhodes  Running Shoes          Sports
# 2      ORD000003   CUST09655  Angie Henderson        Shampoo          Beauty
# 3      ORD000004   CUST02548    Daniel Wagner  Action Figure            Toys
# 4      ORD000005   CUST13224  Cristian Santos        Blender  Home & Kitchen
# ...          ...         ...              ...            ...             ...
# 49995  ORD049996   CUST00712    Kenneth Cantu     Comic Book           Books
# 49996  ORD049997   CUST02448    Carmen Wilson  Running Shoes          Sports
# 49997  ORD049998   CUST12784      Rachel Reed      Sunscreen          Beauty
# 49998  ORD049999   CUST04996    April Edwards         Jacket        Clothing
# 49999  ORD050000   CUST04887   Michael Brooks  Action Figure            Toys
#
# ...

# %%
df.isnull().sum()
# Out:
# order_id              0
# customer_id           0
# customer_name         0
# product               0
# category              0
# price                 0
# quantity              0
# total_amount          0
# order_date            0
# city                  0
# country               0
# payment_method        0
# rating            14255
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# order_id          0
# customer_id       0
# customer_name     0
# product           0
# category          0
# price             0
# quantity          0
# total_amount      0
# order_date        0
# city              0
# country           0
# payment_method    0
# rating            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#         order_id customer_id    customer_name        product  category  \
# 1      ORD000002   CUST03583      Noah Rhodes  Running Shoes    Sports
# 5      ORD000006   CUST13589  Connie Lawrence     Comic Book     Books
# 6      ORD000007   CUST12666  Abigail Shaffer     Board Game      Toys
# 7      ORD000008   CUST02665       Gina Moore         Puzzle      Toys
# 8      ORD000009   CUST08752  Gabrielle Davis       Sneakers  Clothing
# ...          ...         ...              ...            ...       ...
# 49995  ORD049996   CUST00712    Kenneth Cantu     Comic Book     Books
# 49996  ORD049997   CUST02448    Carmen Wilson  Running Shoes    Sports
# 49997  ORD049998   CUST12784      Rachel Reed      Sunscreen    Beauty
# 49998  ORD049999   CUST04996    April Edwards         Jacket  Clothing
# 49999  ORD050000   CUST04887   Michael Brooks  Action Figure      Toys
#
#          price  quantity  total_amount  order_date         city    country  \
# ...
